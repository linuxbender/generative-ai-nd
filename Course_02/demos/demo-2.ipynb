# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ['OPENAI_API_KEY']
print(os.environ['OPENAI_BASE_URL'])

print(os.environ)
# Out:
# https://openai.vocareum.com/v1
# environ({'HOMEBREW_PREFIX': '/opt/homebrew', 'CPPFLAGS': '-I/opt/homebrew/opt/openjdk@24/include', 'COMMAND_MODE': 'unix2003', 'PYTHONUNBUFFERED': '1', 'LC_CTYPE': 'de_CH.UTF-8', 'INFOPATH': '/opt/homebrew/share/info:', 'SHELL': '/bin/zsh', '__CFBundleIdentifier': 'com.jetbrains.intellij', 'TMPDIR': '/var/folders/6w/nh47cmzs7hbgpcbwr96ysx1c0000gn/T/', 'PYTHONIOENCODING': 'UTF-8', 'IJ_RESTARTER_LOG': '/Users/glenn/Library/Logs/JetBrains/IntelliJIdea2025.3/restarter.log', 'HOME': '/Users/glenn', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.4PGXbWdQpl/Listeners', 'HOMEBREW_REPOSITORY': '/opt/homebrew', 'OLDPWD': '/Users/glenn', 'PATH': '/Applications/Docker.app/Contents/Resources/bin:/opt/homebrew/opt/node@24/bin:/opt/homebrew/opt/openjdk@24/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Applications/Keybase.app/Contents/SharedSupport/bin:/Users/glenn/.local/bin:/Users/glenn/Library/Android/sdk/platform-tools/', 'XPC_SERVICE_NAME': 'application.com.jetbrains.intellij.127810263.128111015', 'LOGNAME': 'glenn', 'USER': 'glenn', 'XPC_FLAGS': '0x0', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x13', 'HOMEBREW_CELLAR': '/opt/homebrew/Cellar', 'PWD': '/Users/glenn/Work/Generative-AI-nd/Course_02/demos', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'FORCE_COLOR': '1', 'CLICOLOR_FORCE': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'OPENAI_API_KEY': 'voc-10694876731266774594167694c2af1d65632.81978761', 'OPENAI_BASE_URL': 'https://openai.vocareum.com/v1'})

# %%
from openai import OpenAI

client = OpenAI(api_key=os.environ['OPENAI_API_KEY'], base_url=os.environ['OPENAI_BASE_URL'])

prompt = """How would you measure the diameter of the planet Earth using Eratosthenes method?
"""

completion = client.chat.completions.create(
  model="gpt-4.1",
  messages=[
    {"role": "user", "content": prompt}
  ]
)

print(completion.choices[0].message.content)
# Out:
# **Eratosthenes' method** for measuring the diameter (or more commonly, the circumference) of the Earth is a classic example of ancient scientific reasoning using geometry, observation, and simple tools. Here’s how you can replicate his method step-by-step:
#
# ---
#
# ## **What Eratosthenes Did**
#
# Eratosthenes (c. 276–194 BC) used simple geometry and observations from two locations in Egypt: **Syene** (now Aswan) and **Alexandria**.
#
# ### **1. Observations**
# - At local noon on the **summer solstice** in **Syene**, the Sun was directly overhead (it shone straight down a well).
# - On the same date, at the same time, in **Alexandria** (due north of Syene), objects cast a shadow.
# - Eratosthenes measured the **angle of the shadow** in Alexandria.
#
# ### **2. Measuring the Angle**
# - He found the angle (\(\theta\)) between the stick and the shadow at Alexandria was about **7.2 degrees**.
# - \(7.2^\circ\) is **1/50** of a full circle (\(360^\circ/7.2^\circ = 50\)).
#
# ### **3. Measuring the Distance**
# - He knew or estimated the **distance between Alexandria and Syene** to be about **5,000 stadia** (an ancient unit, roughly 800 km).
#
# ---
#
# ## **Steps to Measure Earth's Diameter**
#
# ### **A. What You Need:**
# - Two cities/towns directly north-south of each other.
# - The ability to measure shadows (a vertical stick or pole — a gnomon).
# - A tape measure, car odometer, or map to estimate the distance between the cities.
# - Protractor, or geometry to calculate the angle from the shadow.
#
# ---
#
# ### **B. The Procedure:**
#
# 1. **Choose Two Locations:**
#    Pick two locations roughly north-south from each other, and far enough apart for noticeable difference (the farther apart, the better, but any separation works for a demonstration).
#
# 2. **On the Same Day (Preferably Summer Solstice):**
#    - At **local noon**, erect a vertical stick at both locations.
#    - In the southern location, ideally the stick will cast no shadow if the Sun is directly overhead. (But in most of the world, both sticks will have some shadow. That’s okay! Just note the angle in both places.)
#
# 3. **Measure the Shadow Angle (\(\theta\))**
#    - Measure the **length of the shadow** and the **height of the stick**.
#    - Use trigonometry to get the angle:
#      \( \theta = \arctan\left(\frac{\text{shadow length}}{\text{stick height}}\right) \)
#    - If the southernmost location's angle is not zero, subtract its angle from the northern location's angle to get the difference.
#
# 4. **Measure the Distance (\(D\))**
#    - Measure the distance, by road, or using latitude difference and Earth's average km per degree latitude (\(\approx 111 \)km per degree).
#    - For example:
#      If the two cities are 800 km apart and are on nearly the same longitude, your calculation is easier.
#
# 5. **Calculate the Earth's Circumference (\(C\))**
#    - The angle you measured (\(\theta\)) is the angle of Earth's arc between the cities.
#    - Proportion:
#      \[
#      \frac{\theta}{360^\circ} = \frac{D}{C}
#      \]
#      Rearranged:
#      \[
#      C = \frac{360^\circ}{\theta} \times D
#      \]
#
# 6. **Calculate Earth's Diameter (\(d\))**
#    - Circumference formula: \(C = \pi d\)
#    - Rearranged:
#      \[
#      d = \frac{C}{\pi}
#      \]
#
# ---
#
# ### **C. Example Calculation**
#
# Suppose:
# - Distance between the two cities, \(D = 800\) km
# - Shadow angle at northern city, \(\theta = 7.2^\circ\) (as Eratosthenes found)
#
# Then:
# 1. Circumference:
#    \[
#    C = \frac{360}{7.2} \times 800 = 50 \times 800 = 40,000\text{ km}
#    \]
# 2. Diameter:
#    \[
#    d = \frac{40,000}{\pi} \approx 12,732\text{ km}
#    \]
#
# (The real equatorial diameter of Earth is about **12,742 km** — remarkably close!)
#
# ---
#
# **Summary Table:**
#
# | Step         | Eratosthenes | You replicate by:                                             |
# |--------------|--------------|---------------------------------------------------------------|
# | Shadow angle | \(7.2^\circ\)| Measure shadow and stick, calculate angle                     |
# | Distance     | 800 km       | Measure between your cities                                   |
# | Proportion   | \(7.2:360\)  | \(\theta:360\)                                               |
# | Calculation  | \(C=50\times D,\, d=C/\pi\) | \(C = \frac{360}{\theta} \times D,\; d = C/\pi\) |
#
# ---
#
# ## **Summary**
#
# - Measure shadow angles at two locations at the same time.
# - Calculate the angle difference (\(\theta\)).
# - Measure distance (\(D\)).
# - Compute circumference: \(C = \frac{360}{\theta} \times D\)
# - Calculate diameter: \(d = \frac{C}{\pi}\)
#
# Thus, using **Eratosthenes’ method**, you can estimate Earth’s diameter **with nothing but sticks, shadows, basic tools, and some math!**

# %%
from openai import OpenAI

client = OpenAI()

prompt = """How would you measure the diameter of the planet Earth using Eratosthenes method?

Give a step by step process to achieve this.
"""

completion = client.chat.completions.create(
  model="gpt-4.1",
  messages=[
    {"role": "user", "content": prompt}
  ]
)

print(completion.choices[0].message.content)
