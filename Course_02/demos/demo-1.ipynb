# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ['OPENAI_API_KEY']

print(os.environ)
# Out:
# environ({'HOMEBREW_PREFIX': '/opt/homebrew', 'CPPFLAGS': '-I/opt/homebrew/opt/openjdk@24/include', 'COMMAND_MODE': 'unix2003', 'PYTHONUNBUFFERED': '1', 'LC_CTYPE': 'de_CH.UTF-8', 'INFOPATH': '/opt/homebrew/share/info:', 'SHELL': '/bin/zsh', '__CFBundleIdentifier': 'com.jetbrains.intellij', 'TMPDIR': '/var/folders/6w/nh47cmzs7hbgpcbwr96ysx1c0000gn/T/', 'PYTHONIOENCODING': 'UTF-8', 'IJ_RESTARTER_LOG': '/Users/glenn/Library/Logs/JetBrains/IntelliJIdea2025.3/restarter.log', 'HOME': '/Users/glenn', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.4PGXbWdQpl/Listeners', 'HOMEBREW_REPOSITORY': '/opt/homebrew', 'OLDPWD': '/Users/glenn', 'PATH': '/Applications/Docker.app/Contents/Resources/bin:/opt/homebrew/opt/node@24/bin:/opt/homebrew/opt/openjdk@24/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Applications/Keybase.app/Contents/SharedSupport/bin:/Users/glenn/.local/bin:/Users/glenn/Library/Android/sdk/platform-tools/', 'XPC_SERVICE_NAME': 'application.com.jetbrains.intellij.127810263.128111015', 'LOGNAME': 'glenn', 'USER': 'glenn', 'XPC_FLAGS': '0x0', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x13', 'HOMEBREW_CELLAR': '/opt/homebrew/Cellar', 'PWD': '/Users/glenn/Work/Generative-AI-nd/Course_02/demos', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'FORCE_COLOR': '1', 'CLICOLOR_FORCE': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline', 'OPENAI_API_KEY': 'voc-10694876731266774594167694c2af1d65632.81978761', 'OPENAI_BASE_URL': 'https://openai.vocareum.com/v1'})

# %%
from openai import OpenAI
from pprint import pprint

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"), base_url=os.getenv("OPENAI_API_BASE_URL"))

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": "Give me a short description of what an embedding is"}
  ],
  logprobs=True,
  top_logprobs=5
)

pprint(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='An embedding is a mathematical representation of data, often used in natural language processing and machine learning to convert words or items into numerical vectors that capture their semantic relationships. Embeddings allow algorithms to understand and analyze the underlying patterns and similarities in the data.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None)

# %%
pprint(completion.choices[0].logprobs)
# Out:
# ChoiceLogprobs(content=[ChatCompletionTokenLogprob(token='An', bytes=[65, 110], logprob=-0.003495542, top_logprobs=[TopLogprob(token='An', bytes=[65, 110], logprob=-0.003495542), TopLogprob(token='In', bytes=[73, 110], logprob=-5.7525096), TopLogprob(token='Embed', bytes=[69, 109, 98, 101, 100], logprob=-8.340653), TopLogprob(token=' An', bytes=[32, 65, 110], logprob=-11.183192), TopLogprob(token='an', bytes=[97, 110], logprob=-11.305596)]), ChatCompletionTokenLogprob(token=' embedding', bytes=[32, 101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=-1.8908588e-05, top_logprobs=[TopLogprob(token=' embedding', bytes=[32, 101, 109, 98, 101, 100, 100, 105, 110, 103], logprob=-1.8908588e-05), TopLogprob(token=' Embed', bytes=[32, 69, 109, 98, 101, 100], logprob=-11.919201), TopLogprob(token=' embeddings', bytes=[32, 101, 109, 98, 101, 100, 100, 105, 110, 103, 115], logprob=-12.248722), TopLogprob(token=' "', bytes=[32, 34], logprob=-12.673521), TopLogprob(token=' embedded', bytes=[32, 101, 109, 98, 101, 100, 100, 101, 100], logprob=-13.370806)]), ChatCompletionTokenLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.008514458, top_logprobs=[TopLogprob(token=' is', bytes=[32, 105, 115], logprob=-0.008514458), TopLogprob(token=' refers', bytes=[32, 114, 101, 102, 101, 114, 115], logprob=-5.076271), TopLogprob(token=' in', bytes=[32, 105, 110], logprob=-6.1645966), TopLogprob(token=' can', bytes=[32, 99, 97, 110], logprob=-9.737177), TopLogprob(token=' represents', bytes=[32, 114, 101, 112, 114, 101, 115, 101, 110, 116, 115], logprob=-10.3784485)]), ChatCompletionTokenLogprob(token=' a', bytes=[32, 97], logprob=-0.0020220205, top_logprobs=[TopLogprob(token=' a', bytes=[32, 97], logprob=-0.0020220205), TopLogprob(token=' the', bytes=[32, 116, 104, 101], logprob=-6.2474365), TopLogprob(token=' essentially', bytes=[32, 101, 115, 115, 101, 110, 116, 105, 97, 108, 108, 121], logprob=-9.981947), TopLogprob(token=' an', bytes=[32, 97, 110], logprob=-11.442541), TopLogprob(token=' representation', bytes=[32, 114, 101, 112, 114, 101, 115, 101, 110, 116, 97, 116, 105, 111, 110], logprob=-11.633734)]), ChatCompletionTokenLogprob(token=' mathematical', bytes=[32, 109, 97, 116, 104, 101, 109, 97, 116, 105, 99, 97, 108], logprob=-1.3289487, top_logprobs=[TopLogprob(token=' mathematical', bytes=[32, 109, 97, 116, 104, 101, 109, 97, 116, 105, 99, 97, 108], logprob=-1.3289487), TopLogprob(token=' way', bytes=[32, 119, 97, 121], logprob=-1.3892553), TopLogprob(token=' representation', bytes=[32, 114, 101, 112, 114, 101, 115, 101, 110, 116, 97, 116, 105, 111, 110], logprob=-1.4139555), TopLogprob(token=' technique', bytes=[32, 116, 101, 99, 104, 110, 105, 113, 117, 101], logprob=-3.0093), TopLogprob(token=' numerical', bytes=[32, 110, 117, 109, 101, 114, 105, 99, 97, 108], logprob=-3.2184465)]), ChatCompletionTokenLogprob(token=' representation', bytes=[32, 114, 101, 112, 114, 101, 115, 101, 110, 116, 97, 116, 105, 111, 110], logprob=-0.03791123, top_logprobs=[TopLogprob(token=' representation', bytes=[32, 114, 101, 112, 114, 101, 115, 101, 110, 116, 97, 116, 105, 111, 110], logprob=-0.03791123), TopLogprob(token=' technique', bytes=[32, 116, 101, 99, 104, 110, 105, 113, 117, 101], logprob=-3.605065), TopLogprob(token=' transformation', bytes=[32, 116, 114, 97, 110, 115, 102, 111, 114, 109, 97, 116, 105, 111, 110], logprob=-5.5873175), TopLogprob(token=' mapping', bytes=[32, 109, 97, 112, 112, 105, 110, 103], logprob=-5.7115107), TopLogprob(token=' vector', bytes=[32, 118, 101, 99, 116, 111, 114], logprob=-7.029195)]), ChatCompletionTokenLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.0054931985, top_logprobs=[TopLogprob(token=' of', bytes=[32, 111, 102], logprob=-0.0054931985), TopLogprob(token=' that', bytes=[32, 116, 104, 97, 116], logprob=-5.426256), TopLogprob(token=' or', bytes=[32, 111, 114], logprob=-7.2972183), TopLogprob(token=' used', bytes=[32, 117, 115, 101, 100], logprob=-8.518297), TopLogprob(token=' in', bytes=[32, 105, 110], l ...
